# %%
import pandas as pd
from sas7bdat import SAS7BDAT

# %%
regio = lambda x: 'North America' if x == "CAN" or x == b'CAN' or x == "USA" or x == b"USA" else 'Rest of World'

def freqs(df,cols,new_col):
    return df.groupby(cols).size().reset_index().rename(columns={0:new_col})

def add_freqs(ds,cols,new_col):
    return pd.merge(ds,freqs(ds,cols,new_col), how='left')

# %%
with SAS7BDAT('dm.sas7bdat') as f:
    dm = f.to_data_frame()
dm = dm[['SUBJID','SEX','AGE','RACE','COUNTRY','ARMCD']]

dm['REGION'] = dm.COUNTRY.map(regio)
dm.shape
# Out:
# [dm.sas7bdat] header length 65536 != 8192
# [dm.sas7bdat] header length 65536 != 8192
# [dm.sas7bdat] header length 65536 != 8192
# [dm.sas7bdat] header length 65536 != 8192
# [dm.sas7bdat] header length 65536 != 8192
# [dm.sas7bdat] header length 65536 != 8192
# [dm.sas7bdat] header length 65536 != 8192
# [dm.sas7bdat] header length 65536 != 8192
# [dm.sas7bdat] header length 65536 != 8192
# [dm.sas7bdat] header length 65536 != 8192
# [dm.sas7bdat] header length 65536 != 8192
# [dm.sas7bdat] header length 65536 != 8192
# [dm.sas7bdat] header length 65536 != 8192
# (889, 7)

# %%
dmx=pd.read_sas('dm.sas7bdat')
dmx = dmx[['SUBJID','SEX','AGE','RACE','COUNTRY','ARMCD']]
dmx = dmx[dmx.ARMCD == b'0']
dmx['REGION'] = dmx.COUNTRY.map(regio)
dmx.shape
# Out:
# (449, 7)

# %%
dmx
# Out:
#          SUBJID   SEX   AGE                                          RACE  \
# 0    b'101-003'  b'M'  51.0  b'NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER'
# 5    b'106-006'  b'F'  56.0                                      b'WHITE'
# 7    b'106-008'  b'M'  53.0                                      b'WHITE'
# 8    b'106-010'  b'F'  58.0                                      b'WHITE'
# 10   b'109-003'  b'M'  40.0                                      b'WHITE'
# 12   b'109-006'  b'F'  41.0                                      b'WHITE'
# 13   b'109-008'  b'F'  54.0                                      b'WHITE'
# 16   b'109-012'  b'F'  48.0                                      b'WHITE'
# 18   b'109-014'  b'F'  53.0                                      b'WHITE'
# 20   b'110-002'  b'F'  39.0                                      b'WHITE'
# 22   b'110-005'  b'F'  45.0                                      b'WHITE'
# 23   b'110-006'  b'M'  57.0                                      b'WHITE'
# 24   b'110-007'  b'F'  38.0                                      b'WHITE'
# 25   b'110-009'  b'M'  44.0                                      b'WHITE'
# 27   b'118-001'  b'F'  52.0           b'AMERICAN INDIAN OR ALASKA NATIVE'
# 28   b'118-002'  b'M'  57.0                                      b'WHITE'
# 30   b'118-005'  b'F'  39.0                                      b'WHITE'
# 31   b'118-007'  b'F'  48.0                  b'BLACK OR AFRICAN AMERICAN'
# 34   b'128-001'  b'M'  47.0                                      b'WHITE'
# 36   b'129-001'  b'M'  59.0                                      b'WHITE'
# 38   b'129-003'  b'F'  49.0                                      b'WHITE'
# 39   b'129-004'  b'F'  54.0                                      b'WHITE'
# 43   b'130-003'  b'M'  57.0                                      b'WHITE'
# 45   b'130-005'  b'F'  50.0                                      b'WHITE'
# 46   b'130-006'  b'F'  47.0                                      b'WHITE'
# 48   b'130-008'  b'F'  58.0                                      b'WHITE'
# 51   b'131-002'  b'M'  52.0                                      b'WHITE'
# 52   b'131-003'  b'F'  46.0                                      b'WHITE'
# 53   b'134-002'  b'F'  53.0                                      b'WHITE'
# 56   b'139-001'  b'M'  48.0                                      b'WHITE'
# ..          ...   ...   ...                                           ...
# 835  b'807-012'  b'M'  36.0                                      b'WHITE'
# 836  b'807-013'  b'F'  45.0                                      b'WHITE'
# 838  b'807-015'  b'M'  40.0                                      b'WHITE'
# 840  b'807-017'  b'M'  52.0                                      b'WHITE'
# 841  b'808-003'  b'M'  44.0                                      b'WHITE'
# 843  b'808-005'  b'F'  54.0                                      b'WHITE'
# 845  b'808-007'  b'F'  26.0                                      b'WHITE'
# 846  b'808-008'  b'M'  35.0                                      b'WHITE'
# 848  b'808-010'  b'M'  48.0                                      b'WHITE'
# 851  b'808-013'  b'M'  41.0                                      b'WHITE'
# 854  b'808-016'  b'F'  41.0                                      b'WHITE'
# 855  b'808-017'  b'F'  42.0                                      b'WHITE'
# 857  b'813-002'  b'M'  38.0                                      b'WHITE'
# 859  b'813-006'  b'F'  44.0                                      b'WHITE'
# 860  b'813-008'  b'M'  54.0                                      b'WHITE'
# 861  b'816-001'  b'M'  51.0                                      b'WHITE'
# 862  b'816-002'  b'F'  36.0                                      b'WHITE'
# 863  b'816-005'  b'F'  47.0                                      b'WHITE'
# 867  b'816-011'  b'M'  33.0                                      b'WHITE'
# 870  b'816-014'  b'F'  31.0                                      b'WHITE'
# 871  b'830-001'  b'M'  49.0                                      b'WHITE'
# 872  b'831-003'  b'F'  46.0                                      b'WHITE'
# 875  b'831-008'  b'F'  43.0                                      b'WHITE'
# 877  b'831-012'  b'F'  44.0                                      b'WHITE'
# 879  b'831-016'  b'F'  57.0                                      b'WHITE'
# 882  b'831-028'  b'F'  55.0                                      b'WHITE'
# 883  b'831-029'  b'F'  54.0                                      b'WHITE'
# 884  b'831-030'  b'F'  50.0                                      b'WHITE'
# 885  b'831-033'  b'M'  56.0                                      b'WHITE'
# 886  b'831-034'  b'F'  51.0                                      b'WHITE'
#
#     COUNTRY ARMCD         REGION
# 0    b'CAN'  b'0'  North America
# 5    b'CAN'  b'0'  North America
# 7    b'CAN'  b'0'  North America
# 8    b'CAN'  b'0'  North America
# 10   b'CAN'  b'0'  North America
# 12   b'CAN'  b'0'  North America
# 13   b'CAN'  b'0'  North America
# 16   b'CAN'  b'0'  North America
# 18   b'CAN'  b'0'  North America
# 20   b'CAN'  b'0'  North America
# 22   b'CAN'  b'0'  North America
# 23   b'CAN'  b'0'  North America
# 24   b'CAN'  b'0'  North America
# 25   b'CAN'  b'0'  North America
# 27   b'USA'  b'0'  North America
# 28   b'USA'  b'0'  North America
# 30   b'USA'  b'0'  North America
# 31   b'USA'  b'0'  North America
# 34   b'USA'  b'0'  North America
# 36   b'USA'  b'0'  North America
# 38   b'USA'  b'0'  North America
# 39   b'USA'  b'0'  North America
# 43   b'CAN'  b'0'  North America
# 45   b'CAN'  b'0'  North America
# 46   b'CAN'  b'0'  North America
# 48   b'CAN'  b'0'  North America
# 51   b'CAN'  b'0'  North America
# 52   b'CAN'  b'0'  North America
# 53   b'USA'  b'0'  North America
# 56   b'USA'  b'0'  North America
# ..      ...   ...            ...
# 835  b'RUS'  b'0'  Rest of World
# 836  b'RUS'  b'0'  Rest of World
# 838  b'RUS'  b'0'  Rest of World
# 840  b'RUS'  b'0'  Rest of World
# 841  b'RUS'  b'0'  Rest of World
# 843  b'RUS'  b'0'  Rest of World
# 845  b'RUS'  b'0'  Rest of World
# 846  b'RUS'  b'0'  Rest of World
# 848  b'RUS'  b'0'  Rest of World
# 851  b'RUS'  b'0'  Rest of World
# 854  b'RUS'  b'0'  Rest of World
# 855  b'RUS'  b'0'  Rest of World
# 857  b'RUS'  b'0'  Rest of World
# 859  b'RUS'  b'0'  Rest of World
# 860  b'RUS'  b'0'  Rest of World
# 861  b'RUS'  b'0'  Rest of World
# 862  b'RUS'  b'0'  Rest of World
# 863  b'RUS'  b'0'  Rest of World
# 867  b'RUS'  b'0'  Rest of World
# 870  b'RUS'  b'0'  Rest of World
# 871  b'ISR'  b'0'  Rest of World
# 872  b'ISR'  b'0'  Rest of World
# 875  b'ISR'  b'0'  Rest of World
# 877  b'ISR'  b'0'  Rest of World
# 879  b'ISR'  b'0'  Rest of World
# 882  b'ISR'  b'0'  Rest of World
# 883  b'ISR'  b'0'  Rest of World
# 884  b'ISR'  b'0'  Rest of World
# 885  b'ISR'  b'0'  Rest of World
# 886  b'ISR'  b'0'  Rest of World
#
# [449 rows x 7 columns]

# %%
dm1=dm[dm.ARMCD == '0']
ref=dm

# %%
def risk_stats(ds,dsref,cols):
    stats={}
    ref=dsref.groupby(cols).size().reset_index().rename(columns={0:'tot'})
    d=pd.merge(ds,ref, how='left')
    d['risk']=1/d.tot
    stats['Average Risk'] = round(d.risk.mean(),5)
    stats['Maximum Risk'] = round(d.risk.max(),5)
    stats['Unique Records'] = int(d[d.risk==1].risk.count())
    stats['Proportion Unique'] = round(stats['Unique Records'] / len(ds),6)
    return {' '.join(sorted(cols)):stats}

# %%
risks=[]

# %%
risk_stats(dm1,ref,['AGE'])
# Out:
# {'AGE': {'Average Risk': 0.04624,
#   'Maximum Risk': 1.0,
#   'Proportion Unique': 0.006682,
#   'Unique Records': 3}}

# %%
risk_stats(dm1,ref,['AGE','SEX','REGION'])
# Out:
# {'AGE REGION SEX': {'Average Risk': 0.14415,
#   'Maximum Risk': 1.0,
#   'Proportion Unique': 0.033408,
#   'Unique Records': 15}}

# %%
risks={}
risks.update( risk_stats(dm1,ref,['AGE']) )
risks.update( risk_stats(dm1,ref,['AGE','SEX','REGION']) )
risks
# Out:
# {'AGE': {'Average Risk': 0.04624,
#   'Maximum Risk': 1.0,
#   'Proportion Unique': 0.006682,
#   'Unique Records': 3},
#  'AGE REGION SEX': {'Average Risk': 0.14415,
#   'Maximum Risk': 1.0,
#   'Proportion Unique': 0.033408,
#   'Unique Records': 15}}

# %%
def variants(dict):
    d=[]
    for i in range(1,2**len(dict)):
        d.append([x for j,x in enumerate(dict) if bin(i)[2:].zfill(len(dict))[j]=='1'])
    return d

# %%
def test_all(ds,ref,vars):
    risks={}
    for variant in variants(vars):
        risks.update(risk_stats(ds,ref,variant) )
    return risks

# %%
test_all(dm1,ref,['AGE','SEX','REGION'])
# Out:
# {'AGE': {'Average Risk': 0.04624,
#   'Maximum Risk': 1.0,
#   'Proportion Unique': 0.006682,
#   'Unique Records': 3},
#  'AGE REGION': {'Average Risk': 0.08032,
#   'Maximum Risk': 1.0,
#   'Proportion Unique': 0.01559,
#   'Unique Records': 7},
#  'AGE REGION SEX': {'Average Risk': 0.14415,
#   'Maximum Risk': 1.0,
#   'Proportion Unique': 0.033408,
#   'Unique Records': 15},
#  'AGE SEX': {'Average Risk': 0.08421,
#   'Maximum Risk': 1.0,
#   'Proportion Unique': 0.008909,
#   'Unique Records': 4},
#  'REGION': {'Average Risk': 0.00227,
#   'Maximum Risk': 0.00592,
#   'Proportion Unique': 0.0,
#   'Unique Records': 0},
#  'REGION SEX': {'Average Risk': 0.00466,
#   'Maximum Risk': 0.01923,
#   'Proportion Unique': 0.0,
#   'Unique Records': 0},
#  'SEX': {'Average Risk': 0.00224,
#   'Maximum Risk': 0.00295,
#   'Proportion Unique': 0.0,
#   'Unique Records': 0}}

# %%
risks['AGE REGION SEX']['Average Risk']
# Out:
# 0.14415
