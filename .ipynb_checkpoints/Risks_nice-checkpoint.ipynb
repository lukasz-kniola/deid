# %%
import pandas as pd
import matplotlib.pyplot as plt

def read_encoded_sas(file):
    for enc in ['iso-8859-1','iso-8859-2','utf-8','unicode','ascii','windows-1250','windows-1252','latin-1']:
        try:
            df=pd.read_sas(file, encoding=enc)
        except:
            pass
        else:
            break
    print ("Encoding used: " + enc)
    return df

# %%
file = 'dm.sas7bdat'
columns = ['SUBJID','SEX','AGE','RACE','COUNTRY','ARMCD']

dmx=read_encoded_sas(file)
dmx = dmx[columns]

#dmx = dmx[dmx.ARMCD == '0']

def deid_country(country):
    return 'North America' if country == "CAN" or country == "USA" else 'Rest of World'
    
dmx['REGION'] = dmx['COUNTRY'].apply(deid_country)
dmx.shape
# Out:
# Encoding used: iso-8859-1
# (889, 7)

# %%
data=dmx[dmx.ARMCD == '0'].copy()
ref=dmx.copy()
data
# Out:
#       SUBJID SEX   AGE                                       RACE COUNTRY  \
# 0    101-003   M  51.0  NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER     CAN
# 5    106-006   F  56.0                                      WHITE     CAN
# 7    106-008   M  53.0                                      WHITE     CAN
# 8    106-010   F  58.0                                      WHITE     CAN
# 10   109-003   M  40.0                                      WHITE     CAN
# 12   109-006   F  41.0                                      WHITE     CAN
# 13   109-008   F  54.0                                      WHITE     CAN
# 16   109-012   F  48.0                                      WHITE     CAN
# 18   109-014   F  53.0                                      WHITE     CAN
# 20   110-002   F  39.0                                      WHITE     CAN
# 22   110-005   F  45.0                                      WHITE     CAN
# 23   110-006   M  57.0                                      WHITE     CAN
# 24   110-007   F  38.0                                      WHITE     CAN
# 25   110-009   M  44.0                                      WHITE     CAN
# 27   118-001   F  52.0           AMERICAN INDIAN OR ALASKA NATIVE     USA
# 28   118-002   M  57.0                                      WHITE     USA
# 30   118-005   F  39.0                                      WHITE     USA
# 31   118-007   F  48.0                  BLACK OR AFRICAN AMERICAN     USA
# 34   128-001   M  47.0                                      WHITE     USA
# 36   129-001   M  59.0                                      WHITE     USA
# 38   129-003   F  49.0                                      WHITE     USA
# 39   129-004   F  54.0                                      WHITE     USA
# 43   130-003   M  57.0                                      WHITE     CAN
# 45   130-005   F  50.0                                      WHITE     CAN
# 46   130-006   F  47.0                                      WHITE     CAN
# 48   130-008   F  58.0                                      WHITE     CAN
# 51   131-002   M  52.0                                      WHITE     CAN
# 52   131-003   F  46.0                                      WHITE     CAN
# 53   134-002   F  53.0                                      WHITE     USA
# 56   139-001   M  48.0                                      WHITE     USA
# ..       ...  ..   ...                                        ...     ...
# 835  807-012   M  36.0                                      WHITE     RUS
# 836  807-013   F  45.0                                      WHITE     RUS
# 838  807-015   M  40.0                                      WHITE     RUS
# 840  807-017   M  52.0                                      WHITE     RUS
# 841  808-003   M  44.0                                      WHITE     RUS
# 843  808-005   F  54.0                                      WHITE     RUS
# 845  808-007   F  26.0                                      WHITE     RUS
# 846  808-008   M  35.0                                      WHITE     RUS
# 848  808-010   M  48.0                                      WHITE     RUS
# 851  808-013   M  41.0                                      WHITE     RUS
# 854  808-016   F  41.0                                      WHITE     RUS
# 855  808-017   F  42.0                                      WHITE     RUS
# 857  813-002   M  38.0                                      WHITE     RUS
# 859  813-006   F  44.0                                      WHITE     RUS
# 860  813-008   M  54.0                                      WHITE     RUS
# 861  816-001   M  51.0                                      WHITE     RUS
# 862  816-002   F  36.0                                      WHITE     RUS
# 863  816-005   F  47.0                                      WHITE     RUS
# 867  816-011   M  33.0                                      WHITE     RUS
# 870  816-014   F  31.0                                      WHITE     RUS
# 871  830-001   M  49.0                                      WHITE     ISR
# 872  831-003   F  46.0                                      WHITE     ISR
# 875  831-008   F  43.0                                      WHITE     ISR
# 877  831-012   F  44.0                                      WHITE     ISR
# 879  831-016   F  57.0                                      WHITE     ISR
# 882  831-028   F  55.0                                      WHITE     ISR
# 883  831-029   F  54.0                                      WHITE     ISR
# 884  831-030   F  50.0                                      WHITE     ISR
# 885  831-033   M  56.0                                      WHITE     ISR
# 886  831-034   F  51.0                                      WHITE     ISR
#
#     ARMCD         REGION
# 0       0  North America
# 5       0  North America
# 7       0  North America
# 8       0  North America
# 10      0  North America
# 12      0  North America
# 13      0  North America
# 16      0  North America
# 18      0  North America
# 20      0  North America
# 22      0  North America
# 23      0  North America
# 24      0  North America
# 25      0  North America
# 27      0  North America
# 28      0  North America
# 30      0  North America
# 31      0  North America
# 34      0  North America
# 36      0  North America
# 38      0  North America
# 39      0  North America
# 43      0  North America
# 45      0  North America
# 46      0  North America
# 48      0  North America
# 51      0  North America
# 52      0  North America
# 53      0  North America
# 56      0  North America
# ..    ...            ...
# 835     0  Rest of World
# 836     0  Rest of World
# 838     0  Rest of World
# 840     0  Rest of World
# 841     0  Rest of World
# 843     0  Rest of World
# 845     0  Rest of World
# 846     0  Rest of World
# 848     0  Rest of World
# 851     0  Rest of World
# 854     0  Rest of World
# 855     0  Rest of World
# 857     0  Rest of World
# 859     0  Rest of World
# 860     0  Rest of World
# 861     0  Rest of World
# 862     0  Rest of World
# 863     0  Rest of World
# 867     0  Rest of World
# 870     0  Rest of World
# 871     0  Rest of World
# 872     0  Rest of World
# 875     0  Rest of World
# 877     0  Rest of World
# 879     0  Rest of World
# 882     0  Rest of World
# 883     0  Rest of World
# 884     0  Rest of World
# 885     0  Rest of World
# 886     0  Rest of World
#
# [449 rows x 7 columns]

# %%
def risk_stats(ds,dsref,cols):
    stats={}
    ref=dsref.groupby(cols).size().reset_index().rename(columns={0:'tot'})
    d=pd.merge(ds,ref, how='left')
    d['risk']=1/d.tot
    stats['Records'] = len(ds)
    stats['Average Risk'] = round(d.risk.mean(),5)
    stats['Maximum Risk'] = round(d.risk.max(),5)
    stats['Unique Records'] = int(d[d.risk==1].risk.count())
    stats['Proportion Unique'] = round(stats['Unique Records'] / len(ds),6)
    return {' '.join(sorted(cols)):stats}

def variants(dict):
    d=[]
    for i in range(1,2**len(dict)):
        d.append([x for j,x in enumerate(dict) if bin(i)[2:].zfill(len(dict))[j]=='1'])
    return d

def test_all(ds,ref,vars):
    risks={}
    for variant in variants(vars):
        risks.update(risk_stats(ds,ref,variant) )
    return risks

# %%
risks = test_all(data,ref,['AGE','COUNTRY','SEX','REGION'])

rr = pd.DataFrame.from_dict(risks, orient='index').sort_values(['Average Risk'])
rr
# Out:
#                         Records  Average Risk  Maximum Risk  Unique Records  \
# SEX                         449       0.00224       0.00295               0
# REGION                      449       0.00227       0.00592               0
# REGION SEX                  449       0.00466       0.01923               0
# COUNTRY                     449       0.01952       0.09091               0
# COUNTRY REGION              449       0.01952       0.09091               0
# COUNTRY REGION SEX          449       0.03827       0.25000               0
# COUNTRY SEX                 449       0.03827       0.25000               0
# AGE                         449       0.04624       1.00000               3
# AGE REGION                  449       0.08032       1.00000               7
# AGE SEX                     449       0.08421       1.00000               4
# AGE REGION SEX              449       0.14415       1.00000              15
# AGE COUNTRY                 449       0.38094       1.00000              73
# AGE COUNTRY REGION          449       0.38094       1.00000              73
# AGE COUNTRY REGION SEX      449       0.52599       1.00000             126
# AGE COUNTRY SEX             449       0.52599       1.00000             126
#
#                         Proportion Unique
# SEX                              0.000000
# REGION                           0.000000
# REGION SEX                       0.000000
# COUNTRY                          0.000000
# COUNTRY REGION                   0.000000
# COUNTRY REGION SEX               0.000000
# COUNTRY SEX                      0.000000
# AGE                              0.006682
# AGE REGION                       0.015590
# AGE SEX                          0.008909
# AGE REGION SEX                   0.033408
# AGE COUNTRY                      0.162584
# AGE COUNTRY REGION               0.162584
# AGE COUNTRY REGION SEX           0.280624
# AGE COUNTRY SEX                  0.280624

# %%
risks['AGE COUNTRY REGION SEX']['Average Risk']
# Out:
# 0.52599

# %%
ax = rr[['Average Risk','Proportion Unique']].plot(kind='bar', title ="Average Risk + Proportion Unique",figsize=(15,10),legend=True, fontsize=12)
ax.axes.axhline(y=0.09, color='red')

# %%
for col in data.columns:
    if col not in ["SUBJID", 'USUBJID']:
        ax = data[col].value_counts().plot(kind='bar', figsize=(15,10),legend=True, fontsize=12, color='steelblue')
        plt.show()
